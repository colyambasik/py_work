# %%
#Номер 3
a = input("Введите длину ребра куба: ")
a = int(a)
print("Площадь боковой поверхности: ", a**2)
print("Объём куба:", a**3)

# %%
#Номер 59
import math
x = float(input("Введите координату x: "))
y = float(input("Введите координату y: "))
print("а)")
point_belongs = False
if x < 0:
    pos_x = float(-x)
else:
    pos_x = x
if y < 0:
    pos_y = float(-y)
else:
    pos_y = y
coordinate_Y = math.sqrt(1**2 - pos_x**2)
if pos_y <= coordinate_Y:
    point_belongs = True
if point_belongs == 1:
    print("Точка принадлежит")
else:
    print("Точка не принадлежит")
print("б)")
point_belongs = False
if x < 0:
    pos_x = -x
else:
    pos_x = x
if y < 0:
    pos_y = -y
else:
    pos_y = y
if pos_x >= 0.05:
    low_X = 0
else:
    low_X = pos_x
coordinate_Y = math.sqrt(1**2 - pos_x**2)
low_Y = math.sqrt(0.5**2 - low_X**2)
if low_Y <= pos_y <= coordinate_Y:
    point_belongs = True
if point_belongs == 1:
    print("Точка принадлежит")
else:
    print("Точка не принадлежит")
print("в)")
point_belongs = False
if x < 0:
    pos_x = -x
else:
    pos_x = x
if y < 0:
    pos_y = -y
else:
    pos_y = y
if (pos_x <= 1) and (pos_y <= 1):
    point_belongs = True
if point_belongs == 1:
    print("Точка принадлежит")
else:
    print("Точка не принадлежит")
print("г)")
point_belongs = False
if x < 0:
    pos_x = -x
else:
    pos_x = x
if y < 0:
    pos_y = -y
else:
    pos_y = y
coordinate_Y = 1 - pos_x
if pos_y <= coordinate_Y:
    point_belongs = True
if point_belongs == 1:
    print("Точка принадлежит")
else:
    print("Точка не принадлежит")
print("д)")
point_belongs = False
if x < 0:
    pos_x = -x
else:
    pos_x = x
if y < 0:
    pos_y = -y
else:
    pos_y = y
coordinate_Y = 1 - pos_x*2
if pos_y <= coordinate_Y:
    point_belongs = True
if point_belongs == 1:
    print("Точка принадлежит")
else:
    print("Точка не принадлежит")
print("е)")
point_belongs = False
if x < 0:
    pos_x = -x
    if y < 0:
        pos_y = -y
    else:
        pos_y = y
    coordinate_Y = (2 - pos_x) / 2
    if pos_y <= coordinate_Y:
        point_belongs = True
else:
    pos_x = x
    if y < 0:
        pos_y = -y
    else:
        pos_y = y
    coordinate_Y = math.sqrt(1 ** 2 - pos_x ** 2)
    if pos_y <= coordinate_Y:
        point_belongs = True
if point_belongs == 1:
    print("Точка принадлежит")
else:
    print("Точка не принадлежит")
print("ж)")
point_belongs = False
if y >= 0:
    pos_y = y
    if x < 0:
        pos_x = abs(x)
    coordinate_Y = (1 - pos_x) * 2
    if pos_y <= coordinate_Y:
        point_belongs = True
if y < 0:
    if (-1 <= x <= 1) and (-1 <= y <= 0):
        point_belongs = True
else:
    pos_x = abs(x)
    pos_y = y
    coordinate_Y = (0 - pos_x)*2 + 2
    if pos_y <= coordinate_Y:
        point_belongs = True
if point_belongs == 1:
    print("Точка принадлежит")
else:
    print("Точка не принадлежит")
print("з)")
point_belongs = False
if (-1 <= x <= 1) and (-2 <= y <= 0):
    point_belongs = True
else:
    pos_x = abs(x)
    coordinate_Y = pos_x
    if y <= coordinate_Y:
        point_belongs = True
if point_belongs == 1:
    print("Точка принадлежит")
else:
    print("Точка не принадлежит")
print("к)")
point_belongs = False
if y >= 1:
    point_belongs = True
else:
    pos_x = abs(x)
    coordinate_Y = pos_x
    if y >= coordinate_Y:
        point_belongs = True
if point_belongs == 1:
    print("Точка принадлежит")
else:
    print("Точка не принадлежит")

# %%
#Номер 120
from tkinter import *
root = Tk()
root.title("Треугольник")
c = Canvas(root, width = 300, height = 300, bg = 'white')
c.pack()
c.create_polygon([100, 100], [150, 100], [80, 170], fill = 'black')
root2 = Tk()
root2.title("Квадрат")
c2 = Canvas(root2, width = 300, height = 300, bg = 'white')
c2.pack()
c2.create_rectangle(80, 150, 170, 80, fill = 'green')
root3 = Tk()
root3.title("Пятиугольник")
c3 = Canvas(root3, width = 300, height = 300, bg = 'white')
c3.pack()
c3.create_polygon([100, 100], [150, 100], [170, 120], [150, 140], [100, 140], fill = 'orange')
root4 = Tk()
root4.title("Шестиугольник")
c4 = Canvas(root4, width = 300, height = 300, bg = 'white')
c4.pack()
c4.create_polygon([120, 100], [140, 120], [140, 140], [120, 160], [100, 140], [100, 120], fill = 'red')
root.mainloop()

# %%
#Номер 62
a = int(input("Введите целое число: "))
if a % 2 == 0:
    print("Число чётное")
else:
    print("Число нечётное")

# %%
#Номер 78(а)
a = float(input("Введите действительное число: "))
n = int(input("Введите натуральное число: "))
print(a**n)

# %%
#Номер 124
import matplotlib.pyplot as plt
s = [143, 310, 80, 90, 220, 140, 1340]
x = range(len(s))
ax = plt.gca()
plt.title("Население стран")
ax.bar(x, s, align='edge')
ax.set_xticks(x)
ax.set_xticklabels(('Россия', 'США', 'Мексика', 'Египет', 'Германия', 'Канада', 'Китай'))
plt.show()

# %%
#Номер 178(в)
import math
array = [10, 6000, 300, 299, 3600, 4560, 100, 64, 121, 81]
kolvo = 0
for el in array:
  if (math.sqrt(el) % 2) == 0:
    print(el, " является квадратом четного числа")
    kolvo += 1
  else:
    print(el, " не является квадратом четного числа")
print("Количество: ", kolvo)

# %%
#Номер 139(б)
import math 
n = int(input("Введите натуральное число: "))
i = 1
b = []
while i <= n:
  number = math.pow(i, 2)
  b.append(number)
  print(i,"-й элемент b последовательности равен ", b[i-1]) 
  i += 1

# %%
#Номер 135 (время выводится, но не обновляется)
from tkinter import *
from datetime import datetime


def number0(x):
    can.create_polygon([10 + x, 10], [20 + x, 20], [20 + x, 40], [10 + x, 50], fill='green')  # 1
    can.create_polygon([25 + x, 20], [15 + x, 10], [55 + x, 10], [45 + x, 20], fill='green')  # 2
    can.create_polygon([60 + x, 10], [60 + x, 50], [50 + x, 40], [50 + x, 20], fill='green')  # 3
    can.create_polygon([10 + x, 51], [20 + x, 61], [20 + x, 81], [10 + x, 91], fill='green')  # 5
    can.create_polygon([15 + x, 91], [25 + x, 81], [45 + x, 81], [55 + x, 91], fill='green')  # 6
    can.create_polygon([60 + x, 91], [50 + x, 81], [50 + x, 61], [60 + x, 51], fill='green')  # 7


def number1(x):
    can.create_polygon([60 + x, 10], [60 + x, 50], [50 + x, 40], [50 + x, 20], fill='green')  # 3
    can.create_polygon([60 + x, 91], [50 + x, 81], [50 + x, 61], [60 + x, 51], fill='green')  # 7


def number2(x):
    can.create_polygon([25 + x, 20], [15 + x, 10], [55 + x, 10], [45 + x, 20], fill='green')  # 2
    can.create_polygon([60 + x, 10], [60 + x, 50], [50 + x, 40], [50 + x, 20], fill='green')  # 3
    can.create_polygon([50 + x, 45], [55 + x, 50], [50 + x, 55], [20 + x, 55], [15 + x, 50], [20 + x, 45], fill='green')  # 4
    can.create_polygon([10 + x, 51], [20 + x, 61], [20 + x, 81], [10 + x, 91], fill='green')  # 5
    can.create_polygon([15 + x, 91], [25 + x, 81], [45 + x, 81], [55 + x, 91], fill='green')  # 6


def number3(x):
    can.create_polygon([25 + x, 20], [15 + x, 10], [55 + x, 10], [45 + x, 20], fill='green')  # 2
    can.create_polygon([60 + x, 10], [60 + x, 50], [50 + x, 40], [50 + x, 20], fill='green')  # 3
    can.create_polygon([50 + x, 45], [55 + x, 50], [50 + x, 55], [20 + x, 55], [15 + x, 50], [20 + x, 45],
                       fill='green')  # 4
    can.create_polygon([15 + x, 91], [25 + x, 81], [45 + x, 81], [55 + x, 91], fill='green')  # 6
    can.create_polygon([60 + x, 91], [50 + x, 81], [50 + x, 61], [60 + x, 51], fill='green')  # 7


def number4(x):
    can.create_polygon([10 + x, 10], [20 + x, 20], [20 + x, 40], [10 + x, 50], fill='green')  # 1
    can.create_polygon([60 + x, 10], [60 + x, 50], [50 + x, 40], [50 + x, 20], fill='green')  # 3
    can.create_polygon([50 + x, 45], [55 + x, 50], [50 + x, 55], [20 + x, 55], [15 + x, 50], [20 + x, 45],
                       fill='green')  # 4
    can.create_polygon([60 + x, 91], [50 + x, 81], [50 + x, 61], [60 + x, 51], fill='green')  # 7


def number5(x):
    can.create_polygon([10 + x, 10], [20 + x, 20], [20 + x, 40], [10 + x, 50], fill='green')  # 1
    can.create_polygon([25 + x, 20], [15 + x, 10], [55 + x, 10], [45 + x, 20], fill='green')  # 2
    can.create_polygon([50 + x, 45], [55 + x, 50], [50 + x, 55], [20 + x, 55], [15 + x, 50], [20 + x, 45],
                       fill='green')  # 4
    can.create_polygon([15 + x, 91], [25 + x, 81], [45 + x, 81], [55 + x, 91], fill='green')  # 6
    can.create_polygon([60 + x, 91], [50 + x, 81], [50 + x, 61], [60 + x, 51], fill='green')  # 7


def number6(x):
    can.create_polygon([10 + x, 10], [20 + x, 20], [20 + x, 40], [10 + x, 50], fill='green')  # 1
    can.create_polygon([25 + x, 20], [15 + x, 10], [55 + x, 10], [45 + x, 20], fill='green')  # 2
    can.create_polygon([50 + x, 45], [55 + x, 50], [50 + x, 55], [20 + x, 55], [15 + x, 50], [20 + x, 45],
                       fill='green')  # 4
    can.create_polygon([10 + x, 51], [20 + x, 61], [20 + x, 81], [10 + x, 91], fill='green')  # 5
    can.create_polygon([15 + x, 91], [25 + x, 81], [45 + x, 81], [55 + x, 91], fill='green')  # 6
    can.create_polygon([60 + x, 91], [50 + x, 81], [50 + x, 61], [60 + x, 51], fill='green')  # 7


def number7(x):
    can.create_polygon([25 + x, 20], [15 + x, 10], [55 + x, 10], [45 + x, 20], fill='green')  # 2
    can.create_polygon([60 + x, 10], [60 + x, 50], [50 + x, 40], [50 + x, 20], fill='green')  # 3
    can.create_polygon([60 + x, 91], [50 + x, 81], [50 + x, 61], [60 + x, 51], fill='green')  # 7


def number8(x):
    can.create_polygon([10 + x, 10], [20 + x, 20], [20 + x, 40], [10 + x, 50], fill='green')  # 1
    can.create_polygon([25 + x, 20], [15 + x, 10], [55 + x, 10], [45 + x, 20], fill='green')  # 2
    can.create_polygon([60 + x, 10], [60 + x, 50], [50 + x, 40], [50 + x, 20], fill='green')  # 3
    can.create_polygon([50 + x, 45], [55 + x, 50], [50 + x, 55], [20 + x, 55], [15 + x, 50], [20 + x, 45],
                       fill='green')  # 4
    can.create_polygon([10 + x, 51], [20 + x, 61], [20 + x, 81], [10 + x, 91], fill='green')  # 5
    can.create_polygon([15 + x, 91], [25 + x, 81], [45 + x, 81], [55 + x, 91], fill='green')  # 6
    can.create_polygon([60 + x, 91], [50 + x, 81], [50 + x, 61], [60 + x, 51], fill='green')  # 7


def number9(x):
    can.create_polygon([10 + x, 10], [20 + x, 20], [20 + x, 40], [10 + x, 50], fill='green')  # 1
    can.create_polygon([25 + x, 20], [15 + x, 10], [55 + x, 10], [45 + x, 20], fill='green')  # 2
    can.create_polygon([60 + x, 10], [60 + x, 50], [50 + x, 40], [50 + x, 20], fill='green')  # 3
    can.create_polygon([50 + x, 45], [55 + x, 50], [50 + x, 55], [20 + x, 55], [15 + x, 50], [20 + x, 45],
                       fill='green')  # 4
    can.create_polygon([15 + x, 91], [25 + x, 81], [45 + x, 81], [55 + x, 91], fill='green')  # 6
    can.create_polygon([60 + x, 91], [50 + x, 81], [50 + x, 61], [60 + x, 51], fill='green')  # 7


window = Tk()
window.title("Электронные часы")
can = Canvas(window, width = 400, height = 400, bg = 'black')
can.pack()
can.create_oval(130, 30, 140, 40, fill = 'green')
can.create_oval(130, 60, 140, 70, fill ='green')
now = datetime.now()
num = now.hour // 10
if num == 0:
    number0(0)
elif num == 1:
    number1(0)
else:
    number2(0)
num = now.hour % 10
if num == 0:
    number0(60)
elif num == 1:
    number1(60)
elif num == 2:
    number2(60)
elif num == 3:
    number3(60)
elif num == 4:
    number4(60)
elif num == 5:
    number5(60)
elif num == 6:
    number6(60)
elif num == 7:
    number7(60)
elif num == 8:
    number8(60)
else:
    number9(60)
num = now.minute // 10
if num == 0:
    number0(140)
elif num == 1:
    number1(140)
elif num == 2:
    number2(140)
elif num == 3:
    number3(140)
elif num == 4:
    number4(140)
else:
    number5(140)
num = now.minute % 10
if num == 0:
    number0(200)
elif num == 1:
    number1(200)
elif num == 2:
    number2(200)
elif num == 3:
    number3(200)
elif num == 4:
    number4(200)
elif num == 5:
    number5(200)
elif num == 6:
    number6(200)
elif num == 7:
    number7(200)
elif num == 8:
    number8(200)
else:
    number9(200)
window.mainloop()

# %%
#Номер 207
n = int(input("Введите натуральное число: "))
i = 1
s = 0
while n != 0:
  a = n % 10
  if (a != 0) and (a != 5):
    s = s + a * i
    i = i * 10
  n = n // 10
print("Получилось ", s)

# %%
#Номер 257(б)
str = 'абпаракеуюва!апв?'
i = 0
while str[i] != '!':
  if str[i] == 'ю':
    print("Буква ю входит в последовательность")
    break
  if str[i+1] == '!':
    print("Буква ю не входит в последовательность")
    break
  i += 1

# %%
#Номер 173
from tkinter import *
import random
window = Tk()
window.title("Прямоугольник")
can = Canvas(window, width = 400, height = 400, bg = 'white')
can.pack()
n = int(input("Введите натуральное число n: "))
arr = [random.randint(0, 300) for i in range(n)]
i = 0
while i < len(arr):
    if (i % 4 == 0) and (i+4 < len(arr)):
        x1 = arr[i] - (arr[i+2] / 2)
        y1 = arr[i+1] - (arr[i+3] / 2)
        x2 = arr[i] + arr[i+2] / 2
        y2 = arr[i+1] + arr[i+3] / 2
        can.create_rectangle(x1, y1, x2, y2, fill = 'green')
    i += 1
window.mainloop()
